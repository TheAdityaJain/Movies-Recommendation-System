# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
import urllib.request

# %%
import csv

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('dataset.csv')

# Sort the DataFrame based on the 'ratings' column
sorted_df = df.sort_values(by='vote_average', ascending=False)

# Write the sorted DataFrame back to a CSV file
sorted_df.to_csv('sorted_file.csv', index=False)

# %%
movies = pd.read_csv('sorted_file.csv')

# %%
movies.head()
# Out:
#        id                        title                 genre  \
# 0  579974                          RRR          Action,Drama
# 1   19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance
# 2     278     The Shawshank Redemption           Drama,Crime
# 3     238                The Godfather           Drama,Crime
# 4     424             Schindler's List     Drama,History,War
#
#   original_language                                           overview  \
# 0                en  A fictional history of two legendary revolutio...
# 1                hi  Raj is a rich, carefree, happy-go-lucky second...
# 2                en  Framed in the 1940s for the double murder of h...
# 3                en  Spanning the years 1945 to 1955, a chronicle o...
# 4                en  The true story of how businessman Oskar Schind...
#
#    popularity release_date  vote_average  vote_count
# 0   11598.000   2022-03-25           9.7       55494
# 1      25.408   1995-10-19           8.7        3731
# ...

# %%
movies=movies[['id','title','overview','genre','vote_average','popularity']]

# %%
def recommend(movies, genre):
    input_genres = genre_input.split(',')
    genre_movies = movies[movies['genre'].notnull() & movies['genre'].apply(lambda x: isinstance(x, str) and any(g in x.split(',') for g in input_genres))]
    if genre_movies.empty:
        return "No movies found for the provided genre(s)."
    vectorizer = CountVectorizer()
    overview_vectors = vectorizer.fit_transform(genre_movies['overview'])
    similarity = cosine_similarity(overview_vectors)
    top_rated_movies = genre_movies.sort_values(by='vote_average', ascending=False)
    return top_rated_movies.head(5)
    pickle.dump(similarity_matrix, open('similarity_rating.pkl', 'wb'))

# %%
genre_input = input("Enter genre: ")
recommended_movies = recommend(movies, genre_input)
print(recommended_movies[['title', 'vote_average']])
# Out:
#                          title  vote_average
# 0                          RRR           9.7
# 2     The Shawshank Redemption           8.7
# 3                The Godfather           8.7
# 1  Dilwale Dulhania Le Jayenge           8.7
# 4             Schindler's List           8.6

# %%
import pickle

# %%
pickle.dump(movies, open('genre_list.pkl', 'wb'))

# %%
pickle.load(open('genre_list.pkl', 'rb'))
# Out:
#           id                          title  \
# 0     579974                            RRR
# 1      19404    Dilwale Dulhania Le Jayenge
# 2        278       The Shawshank Redemption
# 3        238                  The Godfather
# 4        424               Schindler's List
# ...      ...                            ...
# 9908   26715                     Bitch Slap
# 9909  344268  The New Adventures of Aladdin
# 9910   57876                        Area 51
# 9911   13995                Captain America
# 9912  455957                         Domino
#
#                                                overview  \
# 0     A fictional history of two legendary revolutio...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Framed in the 1940s for the double murder of h...
# 3     Spanning the years 1945 to 1955, a chronicle o...
# 4     The true story of how businessman Oskar Schind...
# ...                                                 ...
# ...

# %%
def recommend_rating(movies):
    movies = movies.sort_values(by='vote_average', ascending=False)
    if movies.empty:
        return "No movies found for the provided rating range."
    return movies.head(10)  # Return only top 10 recommendations

# %%
movie23 = recommend_rating(movies)

# %%
print(movie23)
# Out:
#         id                        title  \
# 0   579974                          RRR
# 2      278     The Shawshank Redemption
# 3      238                The Godfather
# 1    19404  Dilwale Dulhania Le Jayenge
# 4      424             Schindler's List
# 5   667257            Impossible Things
# 6      240       The Godfather: Part II
# 23  372754     Dou kyu sei – Classmates
# 19     155              The Dark Knight
# 20     129                Spirited Away
#
#                                              overview  \
# 0   A fictional history of two legendary revolutio...
# 2   Framed in the 1940s for the double murder of h...
# 3   Spanning the years 1945 to 1955, a chronicle o...
# 1   Raj is a rich, carefree, happy-go-lucky second...
# 4   The true story of how businessman Oskar Schind...
# 5   Matilde is a woman who, after the death of her...
# 6   In the continuing saga of the Corleone crime f...
# 23  Rihito Sajo, an honor student with a perfect s...
# ...
